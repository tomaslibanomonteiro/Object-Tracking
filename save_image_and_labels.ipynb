# %%
from utils.DataFactory import generateTrainingSamples, loadInputCsvFromPath, loadInputVideoFromPath
import cv2
import numpy as np
import os

def generate_train_stack():
    # Choose the size of output video
    H,W = (200,420)
    
    # Set the framerate of output video
    fps = 25
    
    # Stack size for training data 
    stack_size = 500

    print("Loading csv datafile")
    df = loadInputCsvFromPath("data/datafiles/2022-03-07_14-07-22_positions-15.csv")
    print("Loading video datafile")
    vcap = loadInputVideoFromPath("data/videos/20220307-1307-214.mp4")
    print("Loading finished!")
    
    
    start_frame = 2000 # Start frame 1775 of sensor data 
    
    print("Generate training stack from video")
    train_data, train_results = generateTrainingSamples(vcap, 
                            df, 
                            start_frame, 
                            out_fps=25, 
                            stack_size=stack_size, 
                            data_size=(W, H))
    
    print("Training stack generated")   
    cv2.destroyAllWindows()
    return train_data, train_results

train_data, train_label = generate_train_stack()
# Out:
# Loading csv datafile
# Loading video datafile
# Frame Rate :  25 frames per second
# Frame count :  125899.0
# Loading finished!
# Generate training stack from video
# Generate training stack from sensor data
# Training stack generated

# %%
def save_stack_mask(stack,path):
    if not os.path.exists(path):
        os.makedirs(path)
    for index, img in enumerate(stack):
        print("Saving {} img in path{}{}{}".format(index+1, path,index+1,"_mask.png"))
        output_path = os.path.join(path,str(index)+'_mask.png')
        ret,threshold = cv2.threshold(img, 0,1,cv2.THRESH_BINARY)
        m = np.where(threshold==1)
        cv2.imwrite(output_path,threshold)

def save_stack_img(stack,path):
    if not os.path.exists(path):
        os.makedirs(path)
    for index, img in enumerate(stack):
        print("Saving {} img in path{}{}{}".format(index+1, path,index+1,".png"))
        output_path = os.path.join(path,str(index)+'.png')
        cv2.imwrite(output_path,img)

# %%
save_stack_img(train_data,"data/dataset/train/img")
save_stack_mask(train_label,"data/dataset/train/label")
# Out:
# Saving 1 img in pathdata/dataset/train/img1.png
# Saving 2 img in pathdata/dataset/train/img2.png
# Saving 3 img in pathdata/dataset/train/img3.png
# Saving 4 img in pathdata/dataset/train/img4.png
# Saving 5 img in pathdata/dataset/train/img5.png
# Saving 6 img in pathdata/dataset/train/img6.png
# Saving 7 img in pathdata/dataset/train/img7.png
# Saving 8 img in pathdata/dataset/train/img8.png
# Saving 9 img in pathdata/dataset/train/img9.png
# Saving 10 img in pathdata/dataset/train/img10.png
# Saving 11 img in pathdata/dataset/train/img11.png
# Saving 12 img in pathdata/dataset/train/img12.png
# Saving 13 img in pathdata/dataset/train/img13.png
# Saving 14 img in pathdata/dataset/train/img14.png
# Saving 15 img in pathdata/dataset/train/img15.png
# Saving 16 img in pathdata/dataset/train/img16.png
# Saving 17 img in pathdata/dataset/train/img17.png
# Saving 18 img in pathdata/dataset/train/img18.png
# Saving 19 img in pathdata/dataset/train/img19.png
# Saving 20 img in pathdata/dataset/train/img20.png
# Saving 21 img in pathdata/dataset/train/img21.png
# Saving 22 img in pathdata/dataset/train/img22.png
# Saving 23 img in pathdata/dataset/train/img23.png
# Saving 24 img in pathdata/dataset/train/img24.png
# Saving 25 img in pathdata/dataset/train/img25.png
# Saving 26 img in pathdata/dataset/train/img26.png
# Saving 27 img in pathdata/dataset/train/img27.png
# Saving 28 img in pathdata/dataset/train/img28.png
# Saving 29 img in pathdata/dataset/train/img29.png
# Saving 30 img in pathdata/dataset/train/img30.png
# Saving 31 img in pathdata/dataset/train/img31.png
# Saving 32 img in pathdata/dataset/train/img32.png
# Saving 33 img in pathdata/dataset/train/img33.png
# Saving 34 img in pathdata/dataset/train/img34.png
# Saving 35 img in pathdata/dataset/train/img35.png
# Saving 36 img in pathdata/dataset/train/img36.png
# Saving 37 img in pathdata/dataset/train/img37.png
# Saving 38 img in pathdata/dataset/train/img38.png
# Saving 39 img in pathdata/dataset/train/img39.png
# Saving 40 img in pathdata/dataset/train/img40.png
# Saving 41 img in pathdata/dataset/train/img41.png
# Saving 42 img in pathdata/dataset/train/img42.png
# Saving 43 img in pathdata/dataset/train/img43.png
# Saving 44 img in pathdata/dataset/train/img44.png
# Saving 45 img in pathdata/dataset/train/img45.png
# Saving 46 img in pathdata/dataset/train/img46.png
# Saving 47 img in pathdata/dataset/train/img47.png
# Saving 48 img in pathdata/dataset/train/img48.png
# Saving 49 img in pathdata/dataset/train/img49.png
# Saving 50 img in pathdata/dataset/train/img50.png
# Saving 51 img in pathdata/dataset/train/img51.png
# Saving 52 img in pathdata/dataset/train/img52.png
# Saving 53 img in pathdata/dataset/train/img53.png
# Saving 54 img in pathdata/dataset/train/img54.png
# Saving 55 img in pathdata/dataset/train/img55.png
# Saving 56 img in pathdata/dataset/train/img56.png
# Saving 57 img in pathdata/dataset/train/img57.png
# Saving 58 img in pathdata/dataset/train/img58.png
# Saving 59 img in pathdata/dataset/train/img59.png
# Saving 60 img in pathdata/dataset/train/img60.png
# Saving 61 img in pathdata/dataset/train/img61.png
# Saving 62 img in pathdata/dataset/train/img62.png
# Saving 63 img in pathdata/dataset/train/img63.png
# Saving 64 img in pathdata/dataset/train/img64.png
# Saving 65 img in pathdata/dataset/train/img65.png
# Saving 66 img in pathdata/dataset/train/img66.png
# Saving 67 img in pathdata/dataset/train/img67.png
# Saving 68 img in pathdata/dataset/train/img68.png
# Saving 69 img in pathdata/dataset/train/img69.png
# Saving 70 img in pathdata/dataset/train/img70.png
# Saving 71 img in pathdata/dataset/train/img71.png
# Saving 72 img in pathdata/dataset/train/img72.png
# Saving 73 img in pathdata/dataset/train/img73.png
# Saving 74 img in pathdata/dataset/train/img74.png
# Saving 75 img in pathdata/dataset/train/img75.png
# Saving 76 img in pathdata/dataset/train/img76.png
# Saving 77 img in pathdata/dataset/train/img77.png
# Saving 78 img in pathdata/dataset/train/img78.png
# Saving 79 img in pathdata/dataset/train/img79.png
# Saving 80 img in pathdata/dataset/train/img80.png
# Saving 81 img in pathdata/dataset/train/img81.png
# Saving 82 img in pathdata/dataset/train/img82.png
# Saving 83 img in pathdata/dataset/train/img83.png
# Saving 84 img in pathdata/dataset/train/img84.png
# Saving 85 img in pathdata/dataset/train/img85.png
# Saving 86 img in pathdata/dataset/train/img86.png
# Saving 87 img in pathdata/dataset/train/img87.png
# Saving 88 img in pathdata/dataset/train/img88.png
# Saving 89 img in pathdata/dataset/train/img89.png
# Saving 90 img in pathdata/dataset/train/img90.png
# Saving 91 img in pathdata/dataset/train/img91.png
# Saving 92 img in pathdata/dataset/train/img92.png
# Saving 93 img in pathdata/dataset/train/img93.png
# Saving 94 img in pathdata/dataset/train/img94.png
# Saving 95 img in pathdata/dataset/train/img95.png
# Saving 96 img in pathdata/dataset/train/img96.png
# Saving 97 img in pathdata/dataset/train/img97.png
# Saving 98 img in pathdata/dataset/train/img98.png
# Saving 99 img in pathdata/dataset/train/img99.png
# Saving 100 img in pathdata/dataset/train/img100.png
# Saving 101 img in pathdata/dataset/train/img101.png
# Saving 102 img in pathdata/dataset/train/img102.png
# Saving 103 img in pathdata/dataset/train/img103.png
# Saving 104 img in pathdata/dataset/train/img104.png
# Saving 105 img in pathdata/dataset/train/img105.png
# Saving 106 img in pathdata/dataset/train/img106.png
# Saving 107 img in pathdata/dataset/train/img107.png
# Saving 108 img in pathdata/dataset/train/img108.png
# Saving 109 img in pathdata/dataset/train/img109.png
# Saving 110 img in pathdata/dataset/train/img110.png
# Saving 111 img in pathdata/dataset/train/img111.png
# Saving 112 img in pathdata/dataset/train/img112.png
# Saving 113 img in pathdata/dataset/train/img113.png
# Saving 114 img in pathdata/dataset/train/img114.png
# Saving 115 img in pathdata/dataset/train/img115.png
# Saving 116 img in pathdata/dataset/train/img116.png
# Saving 117 img in pathdata/dataset/train/img117.png
# Saving 118 img in pathdata/dataset/train/img118.png
# Saving 119 img in pathdata/dataset/train/img119.png
# Saving 120 img in pathdata/dataset/train/img120.png
# Saving 121 img in pathdata/dataset/train/img121.png
# Saving 122 img in pathdata/dataset/train/img122.png
# Saving 123 img in pathdata/dataset/train/img123.png
# Saving 124 img in pathdata/dataset/train/img124.png
# Saving 125 img in pathdata/dataset/train/img125.png
# Saving 126 img in pathdata/dataset/train/img126.png
# Saving 127 img in pathdata/dataset/train/img127.png
# Saving 128 img in pathdata/dataset/train/img128.png
# Saving 129 img in pathdata/dataset/train/img129.png
# Saving 130 img in pathdata/dataset/train/img130.png
# Saving 131 img in pathdata/dataset/train/img131.png
# Saving 132 img in pathdata/dataset/train/img132.png
# Saving 133 img in pathdata/dataset/train/img133.png
# Saving 134 img in pathdata/dataset/train/img134.png
# Saving 135 img in pathdata/dataset/train/img135.png
# Saving 136 img in pathdata/dataset/train/img136.png
# Saving 137 img in pathdata/dataset/train/img137.png
# Saving 138 img in pathdata/dataset/train/img138.png
# Saving 139 img in pathdata/dataset/train/img139.png
# Saving 140 img in pathdata/dataset/train/img140.png
# Saving 141 img in pathdata/dataset/train/img141.png
# Saving 142 img in pathdata/dataset/train/img142.png
# Saving 143 img in pathdata/dataset/train/img143.png
# Saving 144 img in pathdata/dataset/train/img144.png
# Saving 145 img in pathdata/dataset/train/img145.png
# Saving 146 img in pathdata/dataset/train/img146.png
# Saving 147 img in pathdata/dataset/train/img147.png
# Saving 148 img in pathdata/dataset/train/img148.png
# Saving 149 img in pathdata/dataset/train/img149.png
# Saving 150 img in pathdata/dataset/train/img150.png
# Saving 151 img in pathdata/dataset/train/img151.png
# Saving 152 img in pathdata/dataset/train/img152.png
# Saving 153 img in pathdata/dataset/train/img153.png
# Saving 154 img in pathdata/dataset/train/img154.png
# Saving 155 img in pathdata/dataset/train/img155.png
# Saving 156 img in pathdata/dataset/train/img156.png
# Saving 157 img in pathdata/dataset/train/img157.png
# Saving 158 img in pathdata/dataset/train/img158.png
# Saving 159 img in pathdata/dataset/train/img159.png
# Saving 160 img in pathdata/dataset/train/img160.png
# Saving 161 img in pathdata/dataset/train/img161.png
# Saving 162 img in pathdata/dataset/train/img162.png
# Saving 163 img in pathdata/dataset/train/img163.png
# Saving 164 img in pathdata/dataset/train/img164.png
# Saving 165 img in pathdata/dataset/train/img165.png
# Saving 166 img in pathdata/dataset/train/img166.png
# Saving 167 img in pathdata/dataset/train/img167.png
# Saving 168 img in pathdata/dataset/train/img168.png
# Saving 169 img in pathdata/dataset/train/img169.png
# Saving 170 img in pathdata/dataset/train/img170.png
# Saving 171 img in pathdata/dataset/train/img171.png
# Saving 172 img in pathdata/dataset/train/img172.png
# Saving 173 img in pathdata/dataset/train/img173.png
# Saving 174 img in pathdata/dataset/train/img174.png
# Saving 175 img in pathdata/dataset/train/img175.png
# Saving 176 img in pathdata/dataset/train/img176.png
# Saving 177 img in pathdata/dataset/train/img177.png
# Saving 178 img in pathdata/dataset/train/img178.png
# Saving 179 img in pathdata/dataset/train/img179.png
# Saving 180 img in pathdata/dataset/train/img180.png
# Saving 181 img in pathdata/dataset/train/img181.png
# Saving 182 img in pathdata/dataset/train/img182.png
# Saving 183 img in pathdata/dataset/train/img183.png
# Saving 184 img in pathdata/dataset/train/img184.png
# Saving 185 img in pathdata/dataset/train/img185.png
# Saving 186 img in pathdata/dataset/train/img186.png
# Saving 187 img in pathdata/dataset/train/img187.png
# Saving 188 img in pathdata/dataset/train/img188.png
# Saving 189 img in pathdata/dataset/train/img189.png
# Saving 190 img in pathdata/dataset/train/img190.png
# Saving 191 img in pathdata/dataset/train/img191.png
# Saving 192 img in pathdata/dataset/train/img192.png
# Saving 193 img in pathdata/dataset/train/img193.png
# Saving 194 img in pathdata/dataset/train/img194.png
# Saving 195 img in pathdata/dataset/train/img195.png
# Saving 196 img in pathdata/dataset/train/img196.png
# Saving 197 img in pathdata/dataset/train/img197.png
# Saving 198 img in pathdata/dataset/train/img198.png
# Saving 199 img in pathdata/dataset/train/img199.png
# Saving 200 img in pathdata/dataset/train/img200.png
# Saving 201 img in pathdata/dataset/train/img201.png
# Saving 202 img in pathdata/dataset/train/img202.png
# Saving 203 img in pathdata/dataset/train/img203.png
# Saving 204 img in pathdata/dataset/train/img204.png
# Saving 205 img in pathdata/dataset/train/img205.png
# Saving 206 img in pathdata/dataset/train/img206.png
# Saving 207 img in pathdata/dataset/train/img207.png
# Saving 208 img in pathdata/dataset/train/img208.png
# Saving 209 img in pathdata/dataset/train/img209.png
# Saving 210 img in pathdata/dataset/train/img210.png
# Saving 211 img in pathdata/dataset/train/img211.png
# Saving 212 img in pathdata/dataset/train/img212.png
# Saving 213 img in pathdata/dataset/train/img213.png
# Saving 214 img in pathdata/dataset/train/img214.png
# Saving 215 img in pathdata/dataset/train/img215.png
# Saving 216 img in pathdata/dataset/train/img216.png
# Saving 217 img in pathdata/dataset/train/img217.png
# Saving 218 img in pathdata/dataset/train/img218.png
# Saving 219 img in pathdata/dataset/train/img219.png
# Saving 220 img in pathdata/dataset/train/img220.png
# Saving 221 img in pathdata/dataset/train/img221.png
# Saving 222 img in pathdata/dataset/train/img222.png
# Saving 223 img in pathdata/dataset/train/img223.png
# Saving 224 img in pathdata/dataset/train/img224.png
# Saving 225 img in pathdata/dataset/train/img225.png
# Saving 226 img in pathdata/dataset/train/img226.png
# Saving 227 img in pathdata/dataset/train/img227.png
# Saving 228 img in pathdata/dataset/train/img228.png
# Saving 229 img in pathdata/dataset/train/img229.png
# Saving 230 img in pathdata/dataset/train/img230.png
# Saving 231 img in pathdata/dataset/train/img231.png
# Saving 232 img in pathdata/dataset/train/img232.png
# Saving 233 img in pathdata/dataset/train/img233.png
# Saving 234 img in pathdata/dataset/train/img234.png
# Saving 235 img in pathdata/dataset/train/img235.png
# Saving 236 img in pathdata/dataset/train/img236.png
# Saving 237 img in pathdata/dataset/train/img237.png
# Saving 238 img in pathdata/dataset/train/img238.png
# Saving 239 img in pathdata/dataset/train/img239.png
# Saving 240 img in pathdata/dataset/train/img240.png
# Saving 241 img in pathdata/dataset/train/img241.png
# Saving 242 img in pathdata/dataset/train/img242.png
# Saving 243 img in pathdata/dataset/train/img243.png
# Saving 244 img in pathdata/dataset/train/img244.png
# Saving 245 img in pathdata/dataset/train/img245.png
# Saving 246 img in pathdata/dataset/train/img246.png
# Saving 247 img in pathdata/dataset/train/img247.png
# Saving 248 img in pathdata/dataset/train/img248.png
# Saving 249 img in pathdata/dataset/train/img249.png
# Saving 250 img in pathdata/dataset/train/img250.png
# Saving 251 img in pathdata/dataset/train/img251.png
# Saving 252 img in pathdata/dataset/train/img252.png
# Saving 253 img in pathdata/dataset/train/img253.png
# Saving 254 img in pathdata/dataset/train/img254.png
# Saving 255 img in pathdata/dataset/train/img255.png
# Saving 256 img in pathdata/dataset/train/img256.png
# Saving 257 img in pathdata/dataset/train/img257.png
# Saving 258 img in pathdata/dataset/train/img258.png
# Saving 259 img in pathdata/dataset/train/img259.png
# Saving 260 img in pathdata/dataset/train/img260.png
# Saving 261 img in pathdata/dataset/train/img261.png
# Saving 262 img in pathdata/dataset/train/img262.png
# Saving 263 img in pathdata/dataset/train/img263.png
# Saving 264 img in pathdata/dataset/train/img264.png
# Saving 265 img in pathdata/dataset/train/img265.png
# Saving 266 img in pathdata/dataset/train/img266.png
# Saving 267 img in pathdata/dataset/train/img267.png
# Saving 268 img in pathdata/dataset/train/img268.png
# Saving 269 img in pathdata/dataset/train/img269.png
# Saving 270 img in pathdata/dataset/train/img270.png
# Saving 271 img in pathdata/dataset/train/img271.png
# Saving 272 img in pathdata/dataset/train/img272.png
# Saving 273 img in pathdata/dataset/train/img273.png
# Saving 274 img in pathdata/dataset/train/img274.png
# Saving 275 img in pathdata/dataset/train/img275.png
# Saving 276 img in pathdata/dataset/train/img276.png
# Saving 277 img in pathdata/dataset/train/img277.png
# Saving 278 img in pathdata/dataset/train/img278.png
# Saving 279 img in pathdata/dataset/train/img279.png
# Saving 280 img in pathdata/dataset/train/img280.png
# Saving 281 img in pathdata/dataset/train/img281.png
# Saving 282 img in pathdata/dataset/train/img282.png
# Saving 283 img in pathdata/dataset/train/img283.png
# Saving 284 img in pathdata/dataset/train/img284.png
# Saving 285 img in pathdata/dataset/train/img285.png
# Saving 286 img in pathdata/dataset/train/img286.png
# Saving 287 img in pathdata/dataset/train/img287.png
# Saving 288 img in pathdata/dataset/train/img288.png
# Saving 289 img in pathdata/dataset/train/img289.png
# Saving 290 img in pathdata/dataset/train/img290.png
# Saving 291 img in pathdata/dataset/train/img291.png
# Saving 292 img in pathdata/dataset/train/img292.png
# Saving 293 img in pathdata/dataset/train/img293.png
# Saving 294 img in pathdata/dataset/train/img294.png
# Saving 295 img in pathdata/dataset/train/img295.png
# Saving 296 img in pathdata/dataset/train/img296.png
# Saving 297 img in pathdata/dataset/train/img297.png
# Saving 298 img in pathdata/dataset/train/img298.png
# Saving 299 img in pathdata/dataset/train/img299.png
# Saving 300 img in pathdata/dataset/train/img300.png
# Saving 301 img in pathdata/dataset/train/img301.png
# Saving 302 img in pathdata/dataset/train/img302.png
# Saving 303 img in pathdata/dataset/train/img303.png
# Saving 304 img in pathdata/dataset/train/img304.png
# Saving 305 img in pathdata/dataset/train/img305.png
# Saving 306 img in pathdata/dataset/train/img306.png
# Saving 307 img in pathdata/dataset/train/img307.png
# Saving 308 img in pathdata/dataset/train/img308.png
# Saving 309 img in pathdata/dataset/train/img309.png
# Saving 310 img in pathdata/dataset/train/img310.png
# Saving 311 img in pathdata/dataset/train/img311.png
# Saving 312 img in pathdata/dataset/train/img312.png
# Saving 313 img in pathdata/dataset/train/img313.png
# Saving 314 img in pathdata/dataset/train/img314.png
# Saving 315 img in pathdata/dataset/train/img315.png
# Saving 316 img in pathdata/dataset/train/img316.png
# Saving 317 img in pathdata/dataset/train/img317.png
# Saving 318 img in pathdata/dataset/train/img318.png
# Saving 319 img in pathdata/dataset/train/img319.png
# Saving 320 img in pathdata/dataset/train/img320.png
# Saving 321 img in pathdata/dataset/train/img321.png
# Saving 322 img in pathdata/dataset/train/img322.png
# Saving 323 img in pathdata/dataset/train/img323.png
# Saving 324 img in pathdata/dataset/train/img324.png
# Saving 325 img in pathdata/dataset/train/img325.png
# Saving 326 img in pathdata/dataset/train/img326.png
# Saving 327 img in pathdata/dataset/train/img327.png
# Saving 328 img in pathdata/dataset/train/img328.png
# Saving 329 img in pathdata/dataset/train/img329.png
# Saving 330 img in pathdata/dataset/train/img330.png
# Saving 331 img in pathdata/dataset/train/img331.png
# Saving 332 img in pathdata/dataset/train/img332.png
# Saving 333 img in pathdata/dataset/train/img333.png
# Saving 334 img in pathdata/dataset/train/img334.png
# Saving 335 img in pathdata/dataset/train/img335.png
# Saving 336 img in pathdata/dataset/train/img336.png
# Saving 337 img in pathdata/dataset/train/img337.png
# Saving 338 img in pathdata/dataset/train/img338.png
# Saving 339 img in pathdata/dataset/train/img339.png
# Saving 340 img in pathdata/dataset/train/img340.png
# Saving 341 img in pathdata/dataset/train/img341.png
# Saving 342 img in pathdata/dataset/train/img342.png
# Saving 343 img in pathdata/dataset/train/img343.png
# Saving 344 img in pathdata/dataset/train/img344.png
# Saving 345 img in pathdata/dataset/train/img345.png
# Saving 346 img in pathdata/dataset/train/img346.png
# Saving 347 img in pathdata/dataset/train/img347.png
# Saving 348 img in pathdata/dataset/train/img348.png
# Saving 349 img in pathdata/dataset/train/img349.png
# Saving 350 img in pathdata/dataset/train/img350.png
# Saving 351 img in pathdata/dataset/train/img351.png
# Saving 352 img in pathdata/dataset/train/img352.png
# Saving 353 img in pathdata/dataset/train/img353.png
# Saving 354 img in pathdata/dataset/train/img354.png
# Saving 355 img in pathdata/dataset/train/img355.png
# Saving 356 img in pathdata/dataset/train/img356.png
# Saving 357 img in pathdata/dataset/train/img357.png
# Saving 358 img in pathdata/dataset/train/img358.png
# Saving 359 img in pathdata/dataset/train/img359.png
# Saving 360 img in pathdata/dataset/train/img360.png
# Saving 361 img in pathdata/dataset/train/img361.png
# Saving 362 img in pathdata/dataset/train/img362.png
# Saving 363 img in pathdata/dataset/train/img363.png
# Saving 364 img in pathdata/dataset/train/img364.png
# Saving 365 img in pathdata/dataset/train/img365.png
# Saving 366 img in pathdata/dataset/train/img366.png
# Saving 367 img in pathdata/dataset/train/img367.png
# Saving 368 img in pathdata/dataset/train/img368.png
# Saving 369 img in pathdata/dataset/train/img369.png
# Saving 370 img in pathdata/dataset/train/img370.png
# Saving 371 img in pathdata/dataset/train/img371.png
# Saving 372 img in pathdata/dataset/train/img372.png
# Saving 373 img in pathdata/dataset/train/img373.png
# Saving 374 img in pathdata/dataset/train/img374.png
# Saving 375 img in pathdata/dataset/train/img375.png
# Saving 376 img in pathdata/dataset/train/img376.png
# Saving 377 img in pathdata/dataset/train/img377.png
# Saving 378 img in pathdata/dataset/train/img378.png
# Saving 379 img in pathdata/dataset/train/img379.png
# Saving 380 img in pathdata/dataset/train/img380.png
# Saving 381 img in pathdata/dataset/train/img381.png
# Saving 382 img in pathdata/dataset/train/img382.png
# Saving 383 img in pathdata/dataset/train/img383.png
# Saving 384 img in pathdata/dataset/train/img384.png
# Saving 385 img in pathdata/dataset/train/img385.png
# Saving 386 img in pathdata/dataset/train/img386.png
# Saving 387 img in pathdata/dataset/train/img387.png
# Saving 388 img in pathdata/dataset/train/img388.png
# Saving 389 img in pathdata/dataset/train/img389.png
# Saving 390 img in pathdata/dataset/train/img390.png
# Saving 391 img in pathdata/dataset/train/img391.png
# Saving 392 img in pathdata/dataset/train/img392.png
# Saving 393 img in pathdata/dataset/train/img393.png
# Saving 394 img in pathdata/dataset/train/img394.png
# Saving 395 img in pathdata/dataset/train/img395.png
# Saving 396 img in pathdata/dataset/train/img396.png
# Saving 397 img in pathdata/dataset/train/img397.png
# Saving 398 img in pathdata/dataset/train/img398.png
# Saving 399 img in pathdata/dataset/train/img399.png
# Saving 400 img in pathdata/dataset/train/img400.png
# Saving 401 img in pathdata/dataset/train/img401.png
# Saving 402 img in pathdata/dataset/train/img402.png
# Saving 403 img in pathdata/dataset/train/img403.png
# Saving 404 img in pathdata/dataset/train/img404.png
# Saving 405 img in pathdata/dataset/train/img405.png
# Saving 406 img in pathdata/dataset/train/img406.png
# Saving 407 img in pathdata/dataset/train/img407.png
# Saving 408 img in pathdata/dataset/train/img408.png
# Saving 409 img in pathdata/dataset/train/img409.png
# Saving 410 img in pathdata/dataset/train/img410.png
# Saving 411 img in pathdata/dataset/train/img411.png
# Saving 412 img in pathdata/dataset/train/img412.png
# Saving 413 img in pathdata/dataset/train/img413.png
# Saving 414 img in pathdata/dataset/train/img414.png
# Saving 415 img in pathdata/dataset/train/img415.png
# Saving 416 img in pathdata/dataset/train/img416.png
# Saving 417 img in pathdata/dataset/train/img417.png
# Saving 418 img in pathdata/dataset/train/img418.png
# Saving 419 img in pathdata/dataset/train/img419.png
# Saving 420 img in pathdata/dataset/train/img420.png
# Saving 421 img in pathdata/dataset/train/img421.png
# Saving 422 img in pathdata/dataset/train/img422.png
# Saving 423 img in pathdata/dataset/train/img423.png
# Saving 424 img in pathdata/dataset/train/img424.png
# Saving 425 img in pathdata/dataset/train/img425.png
# Saving 426 img in pathdata/dataset/train/img426.png
# Saving 427 img in pathdata/dataset/train/img427.png
# Saving 428 img in pathdata/dataset/train/img428.png
# Saving 429 img in pathdata/dataset/train/img429.png
# Saving 430 img in pathdata/dataset/train/img430.png
# Saving 431 img in pathdata/dataset/train/img431.png
# Saving 432 img in pathdata/dataset/train/img432.png
# Saving 433 img in pathdata/dataset/train/img433.png
# Saving 434 img in pathdata/dataset/train/img434.png
# Saving 435 img in pathdata/dataset/train/img435.png
# Saving 436 img in pathdata/dataset/train/img436.png
# Saving 437 img in pathdata/dataset/train/img437.png
# Saving 438 img in pathdata/dataset/train/img438.png
# Saving 439 img in pathdata/dataset/train/img439.png
# Saving 440 img in pathdata/dataset/train/img440.png
# Saving 441 img in pathdata/dataset/train/img441.png
# Saving 442 img in pathdata/dataset/train/img442.png
# Saving 443 img in pathdata/dataset/train/img443.png
# Saving 444 img in pathdata/dataset/train/img444.png
# Saving 445 img in pathdata/dataset/train/img445.png
# Saving 446 img in pathdata/dataset/train/img446.png
# Saving 447 img in pathdata/dataset/train/img447.png
# Saving 448 img in pathdata/dataset/train/img448.png
# Saving 449 img in pathdata/dataset/train/img449.png
# Saving 450 img in pathdata/dataset/train/img450.png
# Saving 451 img in pathdata/dataset/train/img451.png
# Saving 452 img in pathdata/dataset/train/img452.png
# Saving 453 img in pathdata/dataset/train/img453.png
# Saving 454 img in pathdata/dataset/train/img454.png
# Saving 455 img in pathdata/dataset/train/img455.png
# Saving 456 img in pathdata/dataset/train/img456.png
# Saving 457 img in pathdata/dataset/train/img457.png
# Saving 458 img in pathdata/dataset/train/img458.png
# Saving 459 img in pathdata/dataset/train/img459.png
# Saving 460 img in pathdata/dataset/train/img460.png
# Saving 461 img in pathdata/dataset/train/img461.png
# Saving 462 img in pathdata/dataset/train/img462.png
# Saving 463 img in pathdata/dataset/train/img463.png
# Saving 464 img in pathdata/dataset/train/img464.png
# Saving 465 img in pathdata/dataset/train/img465.png
# Saving 466 img in pathdata/dataset/train/img466.png
# Saving 467 img in pathdata/dataset/train/img467.png
# Saving 468 img in pathdata/dataset/train/img468.png
# Saving 469 img in pathdata/dataset/train/img469.png
# Saving 470 img in pathdata/dataset/train/img470.png
# Saving 471 img in pathdata/dataset/train/img471.png
# Saving 472 img in pathdata/dataset/train/img472.png
# Saving 473 img in pathdata/dataset/train/img473.png
# Saving 474 img in pathdata/dataset/train/img474.png
# Saving 475 img in pathdata/dataset/train/img475.png
# Saving 476 img in pathdata/dataset/train/img476.png
# Saving 477 img in pathdata/dataset/train/img477.png
# Saving 478 img in pathdata/dataset/train/img478.png
# Saving 479 img in pathdata/dataset/train/img479.png
# Saving 480 img in pathdata/dataset/train/img480.png
# Saving 481 img in pathdata/dataset/train/img481.png
# Saving 482 img in pathdata/dataset/train/img482.png
# Saving 483 img in pathdata/dataset/train/img483.png
# Saving 484 img in pathdata/dataset/train/img484.png
# Saving 485 img in pathdata/dataset/train/img485.png
# Saving 486 img in pathdata/dataset/train/img486.png
# Saving 487 img in pathdata/dataset/train/img487.png
# Saving 488 img in pathdata/dataset/train/img488.png
# Saving 489 img in pathdata/dataset/train/img489.png
# Saving 490 img in pathdata/dataset/train/img490.png
# Saving 491 img in pathdata/dataset/train/img491.png
# Saving 492 img in pathdata/dataset/train/img492.png
# Saving 493 img in pathdata/dataset/train/img493.png
# Saving 494 img in pathdata/dataset/train/img494.png
# Saving 495 img in pathdata/dataset/train/img495.png
# Saving 496 img in pathdata/dataset/train/img496.png
# Saving 497 img in pathdata/dataset/train/img497.png
# Saving 498 img in pathdata/dataset/train/img498.png
# Saving 499 img in pathdata/dataset/train/img499.png
# Saving 500 img in pathdata/dataset/train/img500.png
# Saving 1 img in pathdata/dataset/train/label1_mask.png
# Saving 2 img in pathdata/dataset/train/label2_mask.png
# Saving 3 img in pathdata/dataset/train/label3_mask.png
# Saving 4 img in pathdata/dataset/train/label4_mask.png
# Saving 5 img in pathdata/dataset/train/label5_mask.png
# Saving 6 img in pathdata/dataset/train/label6_mask.png
# Saving 7 img in pathdata/dataset/train/label7_mask.png
# Saving 8 img in pathdata/dataset/train/label8_mask.png
# Saving 9 img in pathdata/dataset/train/label9_mask.png
# Saving 10 img in pathdata/dataset/train/label10_mask.png
# Saving 11 img in pathdata/dataset/train/label11_mask.png
# Saving 12 img in pathdata/dataset/train/label12_mask.png
# Saving 13 img in pathdata/dataset/train/label13_mask.png
# Saving 14 img in pathdata/dataset/train/label14_mask.png
# Saving 15 img in pathdata/dataset/train/label15_mask.png
# Saving 16 img in pathdata/dataset/train/label16_mask.png
# Saving 17 img in pathdata/dataset/train/label17_mask.png
# Saving 18 img in pathdata/dataset/train/label18_mask.png
# Saving 19 img in pathdata/dataset/train/label19_mask.png
# Saving 20 img in pathdata/dataset/train/label20_mask.png
# Saving 21 img in pathdata/dataset/train/label21_mask.png
# Saving 22 img in pathdata/dataset/train/label22_mask.png
# Saving 23 img in pathdata/dataset/train/label23_mask.png
# Saving 24 img in pathdata/dataset/train/label24_mask.png
# Saving 25 img in pathdata/dataset/train/label25_mask.png
# Saving 26 img in pathdata/dataset/train/label26_mask.png
# Saving 27 img in pathdata/dataset/train/label27_mask.png
# Saving 28 img in pathdata/dataset/train/label28_mask.png
# Saving 29 img in pathdata/dataset/train/label29_mask.png
# Saving 30 img in pathdata/dataset/train/label30_mask.png
# Saving 31 img in pathdata/dataset/train/label31_mask.png
# Saving 32 img in pathdata/dataset/train/label32_mask.png
# Saving 33 img in pathdata/dataset/train/label33_mask.png
# Saving 34 img in pathdata/dataset/train/label34_mask.png
# Saving 35 img in pathdata/dataset/train/label35_mask.png
# Saving 36 img in pathdata/dataset/train/label36_mask.png
# Saving 37 img in pathdata/dataset/train/label37_mask.png
# Saving 38 img in pathdata/dataset/train/label38_mask.png
# Saving 39 img in pathdata/dataset/train/label39_mask.png
# Saving 40 img in pathdata/dataset/train/label40_mask.png
# Saving 41 img in pathdata/dataset/train/label41_mask.png
# Saving 42 img in pathdata/dataset/train/label42_mask.png
# Saving 43 img in pathdata/dataset/train/label43_mask.png
# Saving 44 img in pathdata/dataset/train/label44_mask.png
# Saving 45 img in pathdata/dataset/train/label45_mask.png
# Saving 46 img in pathdata/dataset/train/label46_mask.png
# Saving 47 img in pathdata/dataset/train/label47_mask.png
# Saving 48 img in pathdata/dataset/train/label48_mask.png
# Saving 49 img in pathdata/dataset/train/label49_mask.png
# Saving 50 img in pathdata/dataset/train/label50_mask.png
# Saving 51 img in pathdata/dataset/train/label51_mask.png
# Saving 52 img in pathdata/dataset/train/label52_mask.png
# Saving 53 img in pathdata/dataset/train/label53_mask.png
# Saving 54 img in pathdata/dataset/train/label54_mask.png
# Saving 55 img in pathdata/dataset/train/label55_mask.png
# Saving 56 img in pathdata/dataset/train/label56_mask.png
# Saving 57 img in pathdata/dataset/train/label57_mask.png
# Saving 58 img in pathdata/dataset/train/label58_mask.png
# Saving 59 img in pathdata/dataset/train/label59_mask.png
# Saving 60 img in pathdata/dataset/train/label60_mask.png
# Saving 61 img in pathdata/dataset/train/label61_mask.png
# Saving 62 img in pathdata/dataset/train/label62_mask.png
# Saving 63 img in pathdata/dataset/train/label63_mask.png
# Saving 64 img in pathdata/dataset/train/label64_mask.png
# Saving 65 img in pathdata/dataset/train/label65_mask.png
# Saving 66 img in pathdata/dataset/train/label66_mask.png
# Saving 67 img in pathdata/dataset/train/label67_mask.png
# Saving 68 img in pathdata/dataset/train/label68_mask.png
# Saving 69 img in pathdata/dataset/train/label69_mask.png
# Saving 70 img in pathdata/dataset/train/label70_mask.png
# Saving 71 img in pathdata/dataset/train/label71_mask.png
# Saving 72 img in pathdata/dataset/train/label72_mask.png
# Saving 73 img in pathdata/dataset/train/label73_mask.png
# Saving 74 img in pathdata/dataset/train/label74_mask.png
# Saving 75 img in pathdata/dataset/train/label75_mask.png
# Saving 76 img in pathdata/dataset/train/label76_mask.png
# Saving 77 img in pathdata/dataset/train/label77_mask.png
# Saving 78 img in pathdata/dataset/train/label78_mask.png
# Saving 79 img in pathdata/dataset/train/label79_mask.png
# Saving 80 img in pathdata/dataset/train/label80_mask.png
# Saving 81 img in pathdata/dataset/train/label81_mask.png
# Saving 82 img in pathdata/dataset/train/label82_mask.png
# Saving 83 img in pathdata/dataset/train/label83_mask.png
# Saving 84 img in pathdata/dataset/train/label84_mask.png
# Saving 85 img in pathdata/dataset/train/label85_mask.png
# Saving 86 img in pathdata/dataset/train/label86_mask.png
# Saving 87 img in pathdata/dataset/train/label87_mask.png
# Saving 88 img in pathdata/dataset/train/label88_mask.png
# Saving 89 img in pathdata/dataset/train/label89_mask.png
# Saving 90 img in pathdata/dataset/train/label90_mask.png
# Saving 91 img in pathdata/dataset/train/label91_mask.png
# Saving 92 img in pathdata/dataset/train/label92_mask.png
# Saving 93 img in pathdata/dataset/train/label93_mask.png
# Saving 94 img in pathdata/dataset/train/label94_mask.png
# Saving 95 img in pathdata/dataset/train/label95_mask.png
# Saving 96 img in pathdata/dataset/train/label96_mask.png
# Saving 97 img in pathdata/dataset/train/label97_mask.png
# Saving 98 img in pathdata/dataset/train/label98_mask.png
# Saving 99 img in pathdata/dataset/train/label99_mask.png
# Saving 100 img in pathdata/dataset/train/label100_mask.png
# Saving 101 img in pathdata/dataset/train/label101_mask.png
# Saving 102 img in pathdata/dataset/train/label102_mask.png
# Saving 103 img in pathdata/dataset/train/label103_mask.png
# Saving 104 img in pathdata/dataset/train/label104_mask.png
# Saving 105 img in pathdata/dataset/train/label105_mask.png
# Saving 106 img in pathdata/dataset/train/label106_mask.png
# Saving 107 img in pathdata/dataset/train/label107_mask.png
# Saving 108 img in pathdata/dataset/train/label108_mask.png
# Saving 109 img in pathdata/dataset/train/label109_mask.png
# Saving 110 img in pathdata/dataset/train/label110_mask.png
# Saving 111 img in pathdata/dataset/train/label111_mask.png
# Saving 112 img in pathdata/dataset/train/label112_mask.png
# Saving 113 img in pathdata/dataset/train/label113_mask.png
# Saving 114 img in pathdata/dataset/train/label114_mask.png
# Saving 115 img in pathdata/dataset/train/label115_mask.png
# Saving 116 img in pathdata/dataset/train/label116_mask.png
# Saving 117 img in pathdata/dataset/train/label117_mask.png
# Saving 118 img in pathdata/dataset/train/label118_mask.png
# Saving 119 img in pathdata/dataset/train/label119_mask.png
# Saving 120 img in pathdata/dataset/train/label120_mask.png
# Saving 121 img in pathdata/dataset/train/label121_mask.png
# Saving 122 img in pathdata/dataset/train/label122_mask.png
# Saving 123 img in pathdata/dataset/train/label123_mask.png
# Saving 124 img in pathdata/dataset/train/label124_mask.png
# Saving 125 img in pathdata/dataset/train/label125_mask.png
# Saving 126 img in pathdata/dataset/train/label126_mask.png
# Saving 127 img in pathdata/dataset/train/label127_mask.png
# Saving 128 img in pathdata/dataset/train/label128_mask.png
# Saving 129 img in pathdata/dataset/train/label129_mask.png
# Saving 130 img in pathdata/dataset/train/label130_mask.png
# Saving 131 img in pathdata/dataset/train/label131_mask.png
# Saving 132 img in pathdata/dataset/train/label132_mask.png
# Saving 133 img in pathdata/dataset/train/label133_mask.png
# Saving 134 img in pathdata/dataset/train/label134_mask.png
# Saving 135 img in pathdata/dataset/train/label135_mask.png
# Saving 136 img in pathdata/dataset/train/label136_mask.png
# Saving 137 img in pathdata/dataset/train/label137_mask.png
# Saving 138 img in pathdata/dataset/train/label138_mask.png
# Saving 139 img in pathdata/dataset/train/label139_mask.png
# Saving 140 img in pathdata/dataset/train/label140_mask.png
# Saving 141 img in pathdata/dataset/train/label141_mask.png
# Saving 142 img in pathdata/dataset/train/label142_mask.png
# Saving 143 img in pathdata/dataset/train/label143_mask.png
# Saving 144 img in pathdata/dataset/train/label144_mask.png
# Saving 145 img in pathdata/dataset/train/label145_mask.png
# Saving 146 img in pathdata/dataset/train/label146_mask.png
# Saving 147 img in pathdata/dataset/train/label147_mask.png
# Saving 148 img in pathdata/dataset/train/label148_mask.png
# Saving 149 img in pathdata/dataset/train/label149_mask.png
# Saving 150 img in pathdata/dataset/train/label150_mask.png
# Saving 151 img in pathdata/dataset/train/label151_mask.png
# Saving 152 img in pathdata/dataset/train/label152_mask.png
# Saving 153 img in pathdata/dataset/train/label153_mask.png
# Saving 154 img in pathdata/dataset/train/label154_mask.png
# Saving 155 img in pathdata/dataset/train/label155_mask.png
# Saving 156 img in pathdata/dataset/train/label156_mask.png
# Saving 157 img in pathdata/dataset/train/label157_mask.png
# Saving 158 img in pathdata/dataset/train/label158_mask.png
# Saving 159 img in pathdata/dataset/train/label159_mask.png
# Saving 160 img in pathdata/dataset/train/label160_mask.png
# Saving 161 img in pathdata/dataset/train/label161_mask.png
# Saving 162 img in pathdata/dataset/train/label162_mask.png
# Saving 163 img in pathdata/dataset/train/label163_mask.png
# Saving 164 img in pathdata/dataset/train/label164_mask.png
# Saving 165 img in pathdata/dataset/train/label165_mask.png
# Saving 166 img in pathdata/dataset/train/label166_mask.png
# Saving 167 img in pathdata/dataset/train/label167_mask.png
# Saving 168 img in pathdata/dataset/train/label168_mask.png
# Saving 169 img in pathdata/dataset/train/label169_mask.png
# Saving 170 img in pathdata/dataset/train/label170_mask.png
# Saving 171 img in pathdata/dataset/train/label171_mask.png
# Saving 172 img in pathdata/dataset/train/label172_mask.png
# Saving 173 img in pathdata/dataset/train/label173_mask.png
# Saving 174 img in pathdata/dataset/train/label174_mask.png
# Saving 175 img in pathdata/dataset/train/label175_mask.png
# Saving 176 img in pathdata/dataset/train/label176_mask.png
# Saving 177 img in pathdata/dataset/train/label177_mask.png
# Saving 178 img in pathdata/dataset/train/label178_mask.png
# Saving 179 img in pathdata/dataset/train/label179_mask.png
# Saving 180 img in pathdata/dataset/train/label180_mask.png
# Saving 181 img in pathdata/dataset/train/label181_mask.png
# Saving 182 img in pathdata/dataset/train/label182_mask.png
# Saving 183 img in pathdata/dataset/train/label183_mask.png
# Saving 184 img in pathdata/dataset/train/label184_mask.png
# Saving 185 img in pathdata/dataset/train/label185_mask.png
# Saving 186 img in pathdata/dataset/train/label186_mask.png
# Saving 187 img in pathdata/dataset/train/label187_mask.png
# Saving 188 img in pathdata/dataset/train/label188_mask.png
# Saving 189 img in pathdata/dataset/train/label189_mask.png
# Saving 190 img in pathdata/dataset/train/label190_mask.png
# Saving 191 img in pathdata/dataset/train/label191_mask.png
# Saving 192 img in pathdata/dataset/train/label192_mask.png
# Saving 193 img in pathdata/dataset/train/label193_mask.png
# Saving 194 img in pathdata/dataset/train/label194_mask.png
# Saving 195 img in pathdata/dataset/train/label195_mask.png
# Saving 196 img in pathdata/dataset/train/label196_mask.png
# Saving 197 img in pathdata/dataset/train/label197_mask.png
# Saving 198 img in pathdata/dataset/train/label198_mask.png
# Saving 199 img in pathdata/dataset/train/label199_mask.png
# Saving 200 img in pathdata/dataset/train/label200_mask.png
# Saving 201 img in pathdata/dataset/train/label201_mask.png
# Saving 202 img in pathdata/dataset/train/label202_mask.png
# Saving 203 img in pathdata/dataset/train/label203_mask.png
# Saving 204 img in pathdata/dataset/train/label204_mask.png
# Saving 205 img in pathdata/dataset/train/label205_mask.png
# Saving 206 img in pathdata/dataset/train/label206_mask.png
# Saving 207 img in pathdata/dataset/train/label207_mask.png
# Saving 208 img in pathdata/dataset/train/label208_mask.png
# Saving 209 img in pathdata/dataset/train/label209_mask.png
# Saving 210 img in pathdata/dataset/train/label210_mask.png
# Saving 211 img in pathdata/dataset/train/label211_mask.png
# Saving 212 img in pathdata/dataset/train/label212_mask.png
# Saving 213 img in pathdata/dataset/train/label213_mask.png
# Saving 214 img in pathdata/dataset/train/label214_mask.png
# Saving 215 img in pathdata/dataset/train/label215_mask.png
# Saving 216 img in pathdata/dataset/train/label216_mask.png
# Saving 217 img in pathdata/dataset/train/label217_mask.png
# Saving 218 img in pathdata/dataset/train/label218_mask.png
# Saving 219 img in pathdata/dataset/train/label219_mask.png
# Saving 220 img in pathdata/dataset/train/label220_mask.png
# Saving 221 img in pathdata/dataset/train/label221_mask.png
# Saving 222 img in pathdata/dataset/train/label222_mask.png
# Saving 223 img in pathdata/dataset/train/label223_mask.png
# Saving 224 img in pathdata/dataset/train/label224_mask.png
# Saving 225 img in pathdata/dataset/train/label225_mask.png
# Saving 226 img in pathdata/dataset/train/label226_mask.png
# Saving 227 img in pathdata/dataset/train/label227_mask.png
# Saving 228 img in pathdata/dataset/train/label228_mask.png
# Saving 229 img in pathdata/dataset/train/label229_mask.png
# Saving 230 img in pathdata/dataset/train/label230_mask.png
# Saving 231 img in pathdata/dataset/train/label231_mask.png
# Saving 232 img in pathdata/dataset/train/label232_mask.png
# Saving 233 img in pathdata/dataset/train/label233_mask.png
# Saving 234 img in pathdata/dataset/train/label234_mask.png
# Saving 235 img in pathdata/dataset/train/label235_mask.png
# Saving 236 img in pathdata/dataset/train/label236_mask.png
# Saving 237 img in pathdata/dataset/train/label237_mask.png
# Saving 238 img in pathdata/dataset/train/label238_mask.png
# Saving 239 img in pathdata/dataset/train/label239_mask.png
# Saving 240 img in pathdata/dataset/train/label240_mask.png
# Saving 241 img in pathdata/dataset/train/label241_mask.png
# Saving 242 img in pathdata/dataset/train/label242_mask.png
# Saving 243 img in pathdata/dataset/train/label243_mask.png
# Saving 244 img in pathdata/dataset/train/label244_mask.png
# Saving 245 img in pathdata/dataset/train/label245_mask.png
# Saving 246 img in pathdata/dataset/train/label246_mask.png
# Saving 247 img in pathdata/dataset/train/label247_mask.png
# Saving 248 img in pathdata/dataset/train/label248_mask.png
# Saving 249 img in pathdata/dataset/train/label249_mask.png
# Saving 250 img in pathdata/dataset/train/label250_mask.png
# Saving 251 img in pathdata/dataset/train/label251_mask.png
# Saving 252 img in pathdata/dataset/train/label252_mask.png
# Saving 253 img in pathdata/dataset/train/label253_mask.png
# Saving 254 img in pathdata/dataset/train/label254_mask.png
# Saving 255 img in pathdata/dataset/train/label255_mask.png
# Saving 256 img in pathdata/dataset/train/label256_mask.png
# Saving 257 img in pathdata/dataset/train/label257_mask.png
# Saving 258 img in pathdata/dataset/train/label258_mask.png
# Saving 259 img in pathdata/dataset/train/label259_mask.png
# Saving 260 img in pathdata/dataset/train/label260_mask.png
# Saving 261 img in pathdata/dataset/train/label261_mask.png
# Saving 262 img in pathdata/dataset/train/label262_mask.png
# Saving 263 img in pathdata/dataset/train/label263_mask.png
# Saving 264 img in pathdata/dataset/train/label264_mask.png
# Saving 265 img in pathdata/dataset/train/label265_mask.png
# Saving 266 img in pathdata/dataset/train/label266_mask.png
# Saving 267 img in pathdata/dataset/train/label267_mask.png
# Saving 268 img in pathdata/dataset/train/label268_mask.png
# Saving 269 img in pathdata/dataset/train/label269_mask.png
# Saving 270 img in pathdata/dataset/train/label270_mask.png
# Saving 271 img in pathdata/dataset/train/label271_mask.png
# Saving 272 img in pathdata/dataset/train/label272_mask.png
# Saving 273 img in pathdata/dataset/train/label273_mask.png
# Saving 274 img in pathdata/dataset/train/label274_mask.png
# Saving 275 img in pathdata/dataset/train/label275_mask.png
# Saving 276 img in pathdata/dataset/train/label276_mask.png
# Saving 277 img in pathdata/dataset/train/label277_mask.png
# Saving 278 img in pathdata/dataset/train/label278_mask.png
# Saving 279 img in pathdata/dataset/train/label279_mask.png
# Saving 280 img in pathdata/dataset/train/label280_mask.png
# Saving 281 img in pathdata/dataset/train/label281_mask.png
# Saving 282 img in pathdata/dataset/train/label282_mask.png
# Saving 283 img in pathdata/dataset/train/label283_mask.png
# Saving 284 img in pathdata/dataset/train/label284_mask.png
# Saving 285 img in pathdata/dataset/train/label285_mask.png
# Saving 286 img in pathdata/dataset/train/label286_mask.png
# Saving 287 img in pathdata/dataset/train/label287_mask.png
# Saving 288 img in pathdata/dataset/train/label288_mask.png
# Saving 289 img in pathdata/dataset/train/label289_mask.png
# Saving 290 img in pathdata/dataset/train/label290_mask.png
# Saving 291 img in pathdata/dataset/train/label291_mask.png
# Saving 292 img in pathdata/dataset/train/label292_mask.png
# Saving 293 img in pathdata/dataset/train/label293_mask.png
# Saving 294 img in pathdata/dataset/train/label294_mask.png
# Saving 295 img in pathdata/dataset/train/label295_mask.png
# Saving 296 img in pathdata/dataset/train/label296_mask.png
# Saving 297 img in pathdata/dataset/train/label297_mask.png
# Saving 298 img in pathdata/dataset/train/label298_mask.png
# Saving 299 img in pathdata/dataset/train/label299_mask.png
# Saving 300 img in pathdata/dataset/train/label300_mask.png
# Saving 301 img in pathdata/dataset/train/label301_mask.png
# Saving 302 img in pathdata/dataset/train/label302_mask.png
# Saving 303 img in pathdata/dataset/train/label303_mask.png
# Saving 304 img in pathdata/dataset/train/label304_mask.png
# Saving 305 img in pathdata/dataset/train/label305_mask.png
# Saving 306 img in pathdata/dataset/train/label306_mask.png
# Saving 307 img in pathdata/dataset/train/label307_mask.png
# Saving 308 img in pathdata/dataset/train/label308_mask.png
# Saving 309 img in pathdata/dataset/train/label309_mask.png
# Saving 310 img in pathdata/dataset/train/label310_mask.png
# Saving 311 img in pathdata/dataset/train/label311_mask.png
# Saving 312 img in pathdata/dataset/train/label312_mask.png
# Saving 313 img in pathdata/dataset/train/label313_mask.png
# Saving 314 img in pathdata/dataset/train/label314_mask.png
# Saving 315 img in pathdata/dataset/train/label315_mask.png
# Saving 316 img in pathdata/dataset/train/label316_mask.png
# Saving 317 img in pathdata/dataset/train/label317_mask.png
# Saving 318 img in pathdata/dataset/train/label318_mask.png
# Saving 319 img in pathdata/dataset/train/label319_mask.png
# Saving 320 img in pathdata/dataset/train/label320_mask.png
# Saving 321 img in pathdata/dataset/train/label321_mask.png
# Saving 322 img in pathdata/dataset/train/label322_mask.png
# Saving 323 img in pathdata/dataset/train/label323_mask.png
# Saving 324 img in pathdata/dataset/train/label324_mask.png
# Saving 325 img in pathdata/dataset/train/label325_mask.png
# Saving 326 img in pathdata/dataset/train/label326_mask.png
# Saving 327 img in pathdata/dataset/train/label327_mask.png
# Saving 328 img in pathdata/dataset/train/label328_mask.png
# Saving 329 img in pathdata/dataset/train/label329_mask.png
# Saving 330 img in pathdata/dataset/train/label330_mask.png
# Saving 331 img in pathdata/dataset/train/label331_mask.png
# Saving 332 img in pathdata/dataset/train/label332_mask.png
# Saving 333 img in pathdata/dataset/train/label333_mask.png
# Saving 334 img in pathdata/dataset/train/label334_mask.png
# Saving 335 img in pathdata/dataset/train/label335_mask.png
# Saving 336 img in pathdata/dataset/train/label336_mask.png
# Saving 337 img in pathdata/dataset/train/label337_mask.png
# Saving 338 img in pathdata/dataset/train/label338_mask.png
# Saving 339 img in pathdata/dataset/train/label339_mask.png
# Saving 340 img in pathdata/dataset/train/label340_mask.png
# Saving 341 img in pathdata/dataset/train/label341_mask.png
# Saving 342 img in pathdata/dataset/train/label342_mask.png
# Saving 343 img in pathdata/dataset/train/label343_mask.png
# Saving 344 img in pathdata/dataset/train/label344_mask.png
# Saving 345 img in pathdata/dataset/train/label345_mask.png
# Saving 346 img in pathdata/dataset/train/label346_mask.png
# Saving 347 img in pathdata/dataset/train/label347_mask.png
# Saving 348 img in pathdata/dataset/train/label348_mask.png
# Saving 349 img in pathdata/dataset/train/label349_mask.png
# Saving 350 img in pathdata/dataset/train/label350_mask.png
# Saving 351 img in pathdata/dataset/train/label351_mask.png
# Saving 352 img in pathdata/dataset/train/label352_mask.png
# Saving 353 img in pathdata/dataset/train/label353_mask.png
# Saving 354 img in pathdata/dataset/train/label354_mask.png
# Saving 355 img in pathdata/dataset/train/label355_mask.png
# Saving 356 img in pathdata/dataset/train/label356_mask.png
# Saving 357 img in pathdata/dataset/train/label357_mask.png
# Saving 358 img in pathdata/dataset/train/label358_mask.png
# Saving 359 img in pathdata/dataset/train/label359_mask.png
# Saving 360 img in pathdata/dataset/train/label360_mask.png
# Saving 361 img in pathdata/dataset/train/label361_mask.png
# Saving 362 img in pathdata/dataset/train/label362_mask.png
# Saving 363 img in pathdata/dataset/train/label363_mask.png
# Saving 364 img in pathdata/dataset/train/label364_mask.png
# Saving 365 img in pathdata/dataset/train/label365_mask.png
# Saving 366 img in pathdata/dataset/train/label366_mask.png
# Saving 367 img in pathdata/dataset/train/label367_mask.png
# Saving 368 img in pathdata/dataset/train/label368_mask.png
# Saving 369 img in pathdata/dataset/train/label369_mask.png
# Saving 370 img in pathdata/dataset/train/label370_mask.png
# Saving 371 img in pathdata/dataset/train/label371_mask.png
# Saving 372 img in pathdata/dataset/train/label372_mask.png
# Saving 373 img in pathdata/dataset/train/label373_mask.png
# Saving 374 img in pathdata/dataset/train/label374_mask.png
# Saving 375 img in pathdata/dataset/train/label375_mask.png
# Saving 376 img in pathdata/dataset/train/label376_mask.png
# Saving 377 img in pathdata/dataset/train/label377_mask.png
# Saving 378 img in pathdata/dataset/train/label378_mask.png
# Saving 379 img in pathdata/dataset/train/label379_mask.png
# Saving 380 img in pathdata/dataset/train/label380_mask.png
# Saving 381 img in pathdata/dataset/train/label381_mask.png
# Saving 382 img in pathdata/dataset/train/label382_mask.png
# Saving 383 img in pathdata/dataset/train/label383_mask.png
# Saving 384 img in pathdata/dataset/train/label384_mask.png
# Saving 385 img in pathdata/dataset/train/label385_mask.png
# Saving 386 img in pathdata/dataset/train/label386_mask.png
# Saving 387 img in pathdata/dataset/train/label387_mask.png
# Saving 388 img in pathdata/dataset/train/label388_mask.png
# Saving 389 img in pathdata/dataset/train/label389_mask.png
# Saving 390 img in pathdata/dataset/train/label390_mask.png
# Saving 391 img in pathdata/dataset/train/label391_mask.png
# Saving 392 img in pathdata/dataset/train/label392_mask.png
# Saving 393 img in pathdata/dataset/train/label393_mask.png
# Saving 394 img in pathdata/dataset/train/label394_mask.png
# Saving 395 img in pathdata/dataset/train/label395_mask.png
# Saving 396 img in pathdata/dataset/train/label396_mask.png
# Saving 397 img in pathdata/dataset/train/label397_mask.png
# Saving 398 img in pathdata/dataset/train/label398_mask.png
# Saving 399 img in pathdata/dataset/train/label399_mask.png
# Saving 400 img in pathdata/dataset/train/label400_mask.png
# Saving 401 img in pathdata/dataset/train/label401_mask.png
# Saving 402 img in pathdata/dataset/train/label402_mask.png
# Saving 403 img in pathdata/dataset/train/label403_mask.png
# Saving 404 img in pathdata/dataset/train/label404_mask.png
# Saving 405 img in pathdata/dataset/train/label405_mask.png
# Saving 406 img in pathdata/dataset/train/label406_mask.png
# Saving 407 img in pathdata/dataset/train/label407_mask.png
# Saving 408 img in pathdata/dataset/train/label408_mask.png
# Saving 409 img in pathdata/dataset/train/label409_mask.png
# Saving 410 img in pathdata/dataset/train/label410_mask.png
# Saving 411 img in pathdata/dataset/train/label411_mask.png
# Saving 412 img in pathdata/dataset/train/label412_mask.png
# Saving 413 img in pathdata/dataset/train/label413_mask.png
# Saving 414 img in pathdata/dataset/train/label414_mask.png
# Saving 415 img in pathdata/dataset/train/label415_mask.png
# Saving 416 img in pathdata/dataset/train/label416_mask.png
# Saving 417 img in pathdata/dataset/train/label417_mask.png
# Saving 418 img in pathdata/dataset/train/label418_mask.png
# Saving 419 img in pathdata/dataset/train/label419_mask.png
# Saving 420 img in pathdata/dataset/train/label420_mask.png
# Saving 421 img in pathdata/dataset/train/label421_mask.png
# Saving 422 img in pathdata/dataset/train/label422_mask.png
# Saving 423 img in pathdata/dataset/train/label423_mask.png
# Saving 424 img in pathdata/dataset/train/label424_mask.png
# Saving 425 img in pathdata/dataset/train/label425_mask.png
# Saving 426 img in pathdata/dataset/train/label426_mask.png
# Saving 427 img in pathdata/dataset/train/label427_mask.png
# Saving 428 img in pathdata/dataset/train/label428_mask.png
# Saving 429 img in pathdata/dataset/train/label429_mask.png
# Saving 430 img in pathdata/dataset/train/label430_mask.png
# Saving 431 img in pathdata/dataset/train/label431_mask.png
# Saving 432 img in pathdata/dataset/train/label432_mask.png
# Saving 433 img in pathdata/dataset/train/label433_mask.png
# Saving 434 img in pathdata/dataset/train/label434_mask.png
# Saving 435 img in pathdata/dataset/train/label435_mask.png
# Saving 436 img in pathdata/dataset/train/label436_mask.png
# Saving 437 img in pathdata/dataset/train/label437_mask.png
# Saving 438 img in pathdata/dataset/train/label438_mask.png
# Saving 439 img in pathdata/dataset/train/label439_mask.png
# Saving 440 img in pathdata/dataset/train/label440_mask.png
# Saving 441 img in pathdata/dataset/train/label441_mask.png
# Saving 442 img in pathdata/dataset/train/label442_mask.png
# Saving 443 img in pathdata/dataset/train/label443_mask.png
# Saving 444 img in pathdata/dataset/train/label444_mask.png
# Saving 445 img in pathdata/dataset/train/label445_mask.png
# Saving 446 img in pathdata/dataset/train/label446_mask.png
# Saving 447 img in pathdata/dataset/train/label447_mask.png
# Saving 448 img in pathdata/dataset/train/label448_mask.png
# Saving 449 img in pathdata/dataset/train/label449_mask.png
# Saving 450 img in pathdata/dataset/train/label450_mask.png
# Saving 451 img in pathdata/dataset/train/label451_mask.png
# Saving 452 img in pathdata/dataset/train/label452_mask.png
# Saving 453 img in pathdata/dataset/train/label453_mask.png
# Saving 454 img in pathdata/dataset/train/label454_mask.png
# Saving 455 img in pathdata/dataset/train/label455_mask.png
# Saving 456 img in pathdata/dataset/train/label456_mask.png
# Saving 457 img in pathdata/dataset/train/label457_mask.png
# Saving 458 img in pathdata/dataset/train/label458_mask.png
# Saving 459 img in pathdata/dataset/train/label459_mask.png
# Saving 460 img in pathdata/dataset/train/label460_mask.png
# Saving 461 img in pathdata/dataset/train/label461_mask.png
# Saving 462 img in pathdata/dataset/train/label462_mask.png
# Saving 463 img in pathdata/dataset/train/label463_mask.png
# Saving 464 img in pathdata/dataset/train/label464_mask.png
# Saving 465 img in pathdata/dataset/train/label465_mask.png
# Saving 466 img in pathdata/dataset/train/label466_mask.png
# Saving 467 img in pathdata/dataset/train/label467_mask.png
# Saving 468 img in pathdata/dataset/train/label468_mask.png
# Saving 469 img in pathdata/dataset/train/label469_mask.png
# Saving 470 img in pathdata/dataset/train/label470_mask.png
# Saving 471 img in pathdata/dataset/train/label471_mask.png
# Saving 472 img in pathdata/dataset/train/label472_mask.png
# Saving 473 img in pathdata/dataset/train/label473_mask.png
# Saving 474 img in pathdata/dataset/train/label474_mask.png
# Saving 475 img in pathdata/dataset/train/label475_mask.png
# Saving 476 img in pathdata/dataset/train/label476_mask.png
# Saving 477 img in pathdata/dataset/train/label477_mask.png
# Saving 478 img in pathdata/dataset/train/label478_mask.png
# Saving 479 img in pathdata/dataset/train/label479_mask.png
# Saving 480 img in pathdata/dataset/train/label480_mask.png
# Saving 481 img in pathdata/dataset/train/label481_mask.png
# Saving 482 img in pathdata/dataset/train/label482_mask.png
# Saving 483 img in pathdata/dataset/train/label483_mask.png
# Saving 484 img in pathdata/dataset/train/label484_mask.png
# Saving 485 img in pathdata/dataset/train/label485_mask.png
# Saving 486 img in pathdata/dataset/train/label486_mask.png
# Saving 487 img in pathdata/dataset/train/label487_mask.png
# Saving 488 img in pathdata/dataset/train/label488_mask.png
# Saving 489 img in pathdata/dataset/train/label489_mask.png
# Saving 490 img in pathdata/dataset/train/label490_mask.png
# Saving 491 img in pathdata/dataset/train/label491_mask.png
# Saving 492 img in pathdata/dataset/train/label492_mask.png
# Saving 493 img in pathdata/dataset/train/label493_mask.png
# Saving 494 img in pathdata/dataset/train/label494_mask.png
# Saving 495 img in pathdata/dataset/train/label495_mask.png
# Saving 496 img in pathdata/dataset/train/label496_mask.png
# Saving 497 img in pathdata/dataset/train/label497_mask.png
# Saving 498 img in pathdata/dataset/train/label498_mask.png
# Saving 499 img in pathdata/dataset/train/label499_mask.png
# Saving 500 img in pathdata/dataset/train/label500_mask.png
